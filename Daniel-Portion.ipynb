# %%
print(__doc__)

import numpy as np
import scipy as sp
import pandas as pd

from sklearn.preprocessing import Imputer
genres_data = pd.read_csv("C:/Users/Vi/Desktop/CMPE 188/genres.csv")
movies_data = pd.read_csv("C:/Users/Vi/Desktop/CMPE 188/movies.csv")
ratings_data = pd.read_csv("C:/Users/Vi/Desktop/CMPE 188/ratings.csv")

movies_data
# Out:
# Automatically created module for IPython interactive environment
#                                  movie  movieId  Comedy  Action  \
# 0                Rogue One / Star Wars        1       0       1
# 1                           Fight Club        2       0       1
# 2                    Lord of the Rings        3       0       1
# 3                               Trolls        4       1       0
# 4                        Despicable Me        5       1       0
# 5                                 Kubo        6       0       1
# 6                             Hangover        7       1       0
# 7                      Captain America        8       0       1
# 8                     The big Lebowski        9       1       0
# 9                        Almost Famous       10       1       0
# 10                        Hunger games       11       0       1
# 11                        Pulp Fiction       12       0       1
# 12                                Sing       13       1       0
# ...

# %%
ratings_data
# Out:
#      userId  movieId  rating
# 0       149        2       5
# 1       149        3       3
# 2       149        5       4
# 3       149        7       4
# 4       149        9       5
# 5       149       10       4
# 6       149       11       4
# 7       149       12       5
# 8       149       13       3
# 9       149       14       3
# 10      149       16       5
# 11      149       18       4
# 12      149       20       4
# 13      149       21       4
# 14      252        1       4
# 15      252        2       5
# 16      252        3       5
# 17      252        4       2
# 18      252        5       1
# 19      252        6       1
# 20      252        7       2
# 21      252        8       4
# 22      252        9       5
# 23      252       11       3
# 24      252       12       5
# 25      252       14       4
# 26      252       15       1
# 27      252       19       5
# 28      252       20       5
# 29      252       21       4
# ..      ...      ...     ...
# ...

# %%
genres_data
# Out:
#              genres  genreId
# 0            Comedy        1
# 1            Action        2
# 2  Sci-Fi.&.Fantasy        3
# 3       Independent        4
# 4          Romantic        5
# 5         Animation        6
# 6             Drama        7

# %%
(trainingData,validationData,testData) = ratings_data.randomSplit([0.6,0.2,0.2])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-668c753585f2> in <module>()
# ----> 1 (trainingData,validationData,testData) = ratings_data.randomSplit([0.6,0.2,0.2])
#
# C:\Users\Vi\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'randomSplit'
