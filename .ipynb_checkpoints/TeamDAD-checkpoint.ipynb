# %%
print(__doc__)

import numpy as np
import scipy as sp
import pandas as pd

from sklearn.preprocessing import Imputer

weather_data = pd.read_csv("Data/weather_data.csv")
trip_data = pd.read_csv("Data/trip_data.csv")
# station_data = pd.read_csv("Bikeshare/station_data.csv")

weather_data
# Out:
# Automatically created module for IPython interactive environment
#             Date  MeanTemperatureF  MeanHumidity  PrecipitationIn   \
# 0      8/29/2013              68.0           75.0                0
# 1      8/30/2013              69.0           70.0                0
# 2      8/31/2013              64.0           75.0                0
# 3       9/1/2013              66.0           68.0                0
# 4       9/2/2013              69.0           77.0                0
# 5       9/3/2013              67.0           65.0                0
# 6       9/4/2013              68.0           72.0                0
# 7       9/5/2013              66.0           74.0                0
# 8       9/6/2013              71.0           58.0                0
# 9       9/7/2013              73.0           59.0                0
# 10      9/8/2013              65.0           70.0                0
# 11      9/9/2013              66.0           70.0                0
# ...

# %%
weather_data.count()
# Out:
# Date                5495
# MeanTemperatureF    5491
# MeanHumidity        5441
# PrecipitationIn     5494
# CloudCover          5494
# Events               888
# zip                 5495
# dtype: int64

# %%
trip_data
# Out:
#        TripID  Duration   StartDate  \
# 0        4576        63   8/29/2013
# 1        4607        70   8/29/2013
# 2        4130        71   8/29/2013
# 3        4251        77   8/29/2013
# 4        4299        83   8/29/2013
# 5        4927       103   8/29/2013
# 6        4500       109   8/29/2013
# 7        4563       111   8/29/2013
# 8        4760       113   8/29/2013
# 9        4258       114   8/29/2013
# 10       4549       125   8/29/2013
# 11       4498       126   8/29/2013
# 12       4965       129   8/29/2013
# 13       4557       130   8/29/2013
# 14       4386       134   8/29/2013
# 15       4749       138   8/29/2013
# 16       4242       141   8/29/2013
# 17       4329       142   8/29/2013
# 18       5097       142   8/29/2013
# 19       5084       144   8/29/2013
# 20       4982       146   8/29/2013
# 21       4417       148   8/29/2013
# 22       4265       151   8/29/2013
# 23       5093       160   8/29/2013
# 24       4168       161   8/29/2013
# ...

# %%
trip_data.count()
# Out:
# TripID              65499
# Duration            65499
# StartDate           65499
# StartStation        65499
# StartTerminal       65499
# SubscriptionType    65499
# ZipCode             61767
# dtype: int64

# %%
station_data
# Out:
#     station_id                                           name        lat  \
# 0            2              San Jose Diridon Caltrain Station  37.329732
# 1            3                          San Jose Civic Center  37.330698
# 2            4                         Santa Clara at Almaden  37.333988
# 3            5                               Adobe on Almaden  37.331415
# 4            6                               San Pedro Square  37.336721
# 5            7                           Paseo de San Antonio  37.333798
# 6            8                            San Salvador at 1st  37.330165
# 7            9                                      Japantown  37.348742
# 8           10                             San Jose City Hall  37.337391
# 9           11                                    MLK Library  37.335885
# 10          12                         SJSU 4th at San Carlos  37.332808
# 11          13                                  St James Park  37.339301
# ...

# %%
station_data.count()
# Out:
# station_id      70
# name            70
# lat             70
# long            70
# dockcount       70
# landmark        70
# installation    70
# dtype: int64

# %%
trip_data_ed = trip_data
